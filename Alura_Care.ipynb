# %%
import pandas as pd

res_exames = pd.read_csv("./exames.csv")
res_exames.head()
# Out:
#          id diagnostico  exame_1  exame_2  exame_3  exame_4  exame_5  exame_6  \
# 0    842302           M    17.99    10.38   122.80   103.78   1001.0  0.11840
# 1    842517           M    20.57    17.77   132.90   103.78   1326.0  0.08474
# 2  84300903           M    19.69    21.25   130.00   103.78   1203.0  0.10960
# 3  84348301           M    11.42    20.38    77.58   103.78    386.1  0.14250
# 4  84358402           M    20.29    14.34   135.10   103.78   1297.0  0.10030
#
#    exame_7  exame_8  ...  exame_24  exame_25  exame_26  exame_27  exame_28  \
# 0  0.27760   0.3001  ...    184.60    2019.0    0.1622    0.6656    0.7119
# 1  0.07864   0.0869  ...    158.80    1956.0    0.1238    0.1866    0.2416
# 2  0.15990   0.1974  ...    152.50    1709.0    0.1444    0.4245    0.4504
# 3  0.28390   0.2414  ...     98.87     567.7    0.2098    0.8663    0.6869
# 4  0.13280   0.1980  ...    152.20    1575.0    0.1374    0.2050    0.4000
#
#    exame_29  exame_30  exame_31  exame_32  exame_33
# 0     0.786    0.2654    0.4601   0.11890       NaN
# 1     0.786    0.1860    0.2750   0.08902       NaN
# 2     0.786    0.2430    0.3613   0.08758       NaN
# 3     0.786    0.2575    0.6638   0.17300       NaN
# 4     0.786    0.1625    0.2364   0.07678  0.854454
#
# [5 rows x 35 columns]

# %%
res_exames.isnull().sum()
# Out:
# id               0
# diagnostico      0
# exame_1          0
# exame_2          0
# exame_3          0
# exame_4          0
# exame_5          0
# exame_6          0
# exame_7          0
# exame_8          0
# exame_9          0
# exame_10         0
# exame_11         0
# exame_12         0
# exame_13         0
# exame_14         0
# exame_15         0
# exame_16         0
# exame_17         0
# exame_18         0
# exame_19         0
# exame_20         0
# exame_21         0
# exame_22         0
# exame_23         0
# exame_24         0
# exame_25         0
# exame_26         0
# exame_27         0
# exame_28         0
# exame_29         0
# exame_30         0
# exame_31         0
# exame_32         0
# exame_33       419
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from numpy import random

SEED = 123143
random.seed(SEED)

valores_exames = res_exames.drop(columns=['id', 'diagnostico'])
diagnostico = res_exames.diagnostico
valores_exames_v1 = valores_exames.drop(columns='exame_33')

treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v1, diagnostico, test_size = 0.3)

# %%
treino_x.head()
# Out:
#      exame_1  exame_2  exame_3  exame_4  exame_5  exame_6  exame_7  exame_8  \
# 268    12.87    16.21    82.38   103.78    512.2  0.09425  0.06219  0.03900
# 422    11.61    16.02    75.46   103.78    408.2  0.10880  0.11680  0.07097
# 168    17.47    24.68   116.10   103.78    984.6  0.10490  0.16030  0.21590
# 501    13.82    24.49    92.33   103.78    595.9  0.11620  0.16810  0.13570
# 563    20.92    25.09   143.00   103.78   1347.0  0.10990  0.22360  0.31740
#
#      exame_9  exame_10  ...  exame_23  exame_24  exame_25  exame_26  exame_27  \
# 268  0.01615    0.2010  ...     23.64     89.27     597.5    0.1256    0.1808
# 422  0.04497    0.1886  ...     19.67     81.93     475.7    0.1415    0.2170
# 168  0.10430    0.1538  ...     32.33    155.30    1660.0    0.1376    0.3830
# 501  0.06759    0.2275  ...     32.94    106.00     788.0    0.1794    0.3966
# 563  0.14740    0.2149  ...     29.41    179.10    1819.0    0.1407    0.4186
#
#      exame_28  exame_29  exame_30  exame_31  exame_32
# 268    0.1992     0.786    0.0578    0.3604   0.07062
# 422    0.2302     0.786    0.1105    0.2787   0.07427
# 168    0.4890     0.786    0.1721    0.2160   0.09300
# 501    0.3381     0.786    0.1521    0.3651   0.11830
# 563    0.6599     0.786    0.2542    0.2929   0.09873
#
# [5 rows x 32 columns]

# %%
treino_y.head()
# Out:
# 268    B
# 422    B
# 168    M
# 501    M
# 563    M
# Name: diagnostico, dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier

classificador = RandomForestClassifier(n_estimators = 100)
classificador.fit(treino_x, treino_y)
print("Resultado da classificação %.2f%%." % (classificador.score(teste_x, teste_y)*100))
# Out:
# Resultado da classificação 92.40%.

# %%
from sklearn.dummy import DummyClassifier

SEED = 123143
random.seed(SEED)

classificador_bobo = DummyClassifier(strategy = "most_frequent")
classificador_bobo.fit(treino_x, treino_y)
print("Resultado da classificação boba %.2f%%." % (classificador_bobo.score(teste_x, teste_y)*100))
# Out:
# Resultado da classificação boba 66.67%.

# %%
dados_plot = pd.concat([diagnostico, valores_exames_v1.iloc[:,0:10]], axis=1)
dados_plot = pd.melt(dados_plot, id_vars='diagnostico', var_name='exames', value_name='valores')
dados_plot.head()
# Out:
#   diagnostico   exames  valores
# 0           M  exame_1    17.99
# 1           M  exame_1    20.57
# 2           M  exame_1    19.69
# 3           M  exame_1    11.42
# 4           M  exame_1    20.29

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.xticks(rotation = 90)
sns.violinplot(x = 'exames', y = 'valores', hue = 'diagnostico', data = dados_plot)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

padronizador = StandardScaler()
padronizador.fit(valores_exames_v1)
valores_exames_v2 = padronizador.transform(valores_exames_v1)
valores_exames_v2 = pd.DataFrame(data = valores_exames_v2, columns=valores_exames_v1.keys())

dados_plot = pd.concat([diagnostico, valores_exames_v2.iloc[:,0:10]], axis=1)
dados_plot = pd.melt(dados_plot, id_vars='diagnostico', var_name='exames', value_name='valores')
dados_plot.head()

plt.figure(figsize=(10,10))
plt.xticks(rotation = 90)
sns.violinplot(x = 'exames', y = 'valores', hue = 'diagnostico', data = dados_plot, split=True)

# %%
def grafico_violino(valores, inicio, fim):
    dados_plot = pd.concat([diagnostico, valores.iloc[:,inicio:fim]], axis=1)
    dados_plot = pd.melt(dados_plot, id_vars='diagnostico', var_name='exames', value_name='valores')
    plt.figure(figsize=(10,10))
    plt.xticks(rotation = 90)
    sns.violinplot(x = 'exames', y = 'valores', hue = 'diagnostico', data = dados_plot, split=True)
grafico_violino(valores_exames_v2, 10, 21)

# %%
grafico_violino(valores_exames_v2, 21, 32)

# %%
valores_exames_v3 = valores_exames_v2.drop(columns=['exame_4','exame_29'])
def classificar(valores):
    SEED = 1234
    random.seed(SEED)
    treino_x, teste_x, treino_y, teste_y = train_test_split(valores, diagnostico, test_size = 0.3)
    classificador = RandomForestClassifier(n_estimators = 100)
    classificador.fit(treino_x, treino_y)
    print("Resultado da classificação %.2f%%." % (classificador.score(teste_x, teste_y)*100))
classificar(valores_exames_v3)
# Out:
# Resultado da classificação 92.98%.

# %%
valores_exames_v5 = valores_exames_v3.drop(columns=['exame_3', 'exame_24'])
classifica

# %%
matriz_correlacao = valores_exames_v3.corr()
plt.figure(figsize=(17,15))
sns.heatmap(matriz_correlacao, annot = True, fmt = '.1')

# %%
matriz_correlacao_v1 = matriz_correlacao[matriz_correlacao > 0.99]
matriz_correlacao_v1
# Out:
#            exame_1  exame_2   exame_3  exame_5  exame_6  exame_7  exame_8  \
# exame_1   1.000000      NaN  0.997855      NaN      NaN      NaN      NaN
# exame_2        NaN      1.0       NaN      NaN      NaN      NaN      NaN
# exame_3   0.997855      NaN  1.000000      NaN      NaN      NaN      NaN
# exame_5        NaN      NaN       NaN      1.0      NaN      NaN      NaN
# exame_6        NaN      NaN       NaN      NaN      1.0      NaN      NaN
# exame_7        NaN      NaN       NaN      NaN      NaN      1.0      NaN
# exame_8        NaN      NaN       NaN      NaN      NaN      NaN      1.0
# exame_9        NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_10       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_11       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_12       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_13       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_14       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_15       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_16       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_17       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_18       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_19       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_20       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_21       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_22       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_23       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_24       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_25       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_26       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_27       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_28       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_30       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_31       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_32       NaN      NaN       NaN      NaN      NaN      NaN      NaN
#
#           exame_9  exame_10  exame_11  ...  exame_22  exame_23  exame_24  \
# exame_1       NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_2       NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_3       NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_5       NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_6       NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_7       NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_8       NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_9       1.0       NaN       NaN  ...       NaN       NaN       NaN
# exame_10      NaN       1.0       NaN  ...       NaN       NaN       NaN
# exame_11      NaN       NaN       1.0  ...       NaN       NaN       NaN
# exame_12      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_13      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_14      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_15      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_16      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_17      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_18      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_19      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_20      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_21      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_22      NaN       NaN       NaN  ...  1.000000       NaN  0.993708
# exame_23      NaN       NaN       NaN  ...       NaN       1.0       NaN
# exame_24      NaN       NaN       NaN  ...  0.993708       NaN  1.000000
# exame_25      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_26      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_27      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_28      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_30      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_31      NaN       NaN       NaN  ...       NaN       NaN       NaN
# exame_32      NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#           exame_25  exame_26  exame_27  exame_28  exame_30  exame_31  exame_32
# exame_1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_2        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_3        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_5        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_6        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_7        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_8        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_9        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_10       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_11       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_12       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_13       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_14       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_15       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_16       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_17       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_18       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_19       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_20       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_21       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_22       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_23       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_24       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# exame_25       1.0       NaN       NaN       NaN       NaN       NaN       NaN
# exame_26       NaN       1.0       NaN       NaN       NaN       NaN       NaN
# exame_27       NaN       NaN       1.0       NaN       NaN       NaN       NaN
# exame_28       NaN       NaN       NaN       1.0       NaN       NaN       NaN
# exame_30       NaN       NaN       NaN       NaN       1.0       NaN       NaN
# exame_31       NaN       NaN       NaN       NaN       NaN       1.0       NaN
# exame_32       NaN       NaN       NaN       NaN       NaN       NaN       1.0
#
# [30 rows x 30 columns]

# %%
matriz_correlacao_v2 = matriz_correlacao_v1.sum()
matriz_correlacao_v2
# Out:
# exame_1     1.997855
# exame_2     1.000000
# exame_3     1.997855
# exame_5     1.000000
# exame_6     1.000000
# exame_7     1.000000
# exame_8     1.000000
# exame_9     1.000000
# exame_10    1.000000
# exame_11    1.000000
# exame_12    1.000000
# exame_13    1.000000
# exame_14    1.000000
# exame_15    1.000000
# exame_16    1.000000
# exame_17    1.000000
# exame_18    1.000000
# exame_19    1.000000
# exame_20    1.000000
# exame_21    1.000000
# exame_22    1.993708
# exame_23    1.000000
# exame_24    1.993708
# exame_25    1.000000
# exame_26    1.000000
# exame_27    1.000000
# exame_28    1.000000
# exame_30    1.000000
# exame_31    1.000000
# exame_32    1.000000
# dtype: float64

# %%
variaveis_correlacionadas = matriz_correlacao_v2[matriz_correlacao_v2>1]
variaveis_correlacionadas
# Out:
# exame_1     1.997855
# exame_3     1.997855
# exame_22    1.993708
# exame_24    1.993708
# dtype: float64

# %%
valores_exames_v4 = valores_exames_v3.drop(columns=variaveis_correlacionadas.keys())
valores_exames_v4
# Out:
#       exame_2   exame_5   exame_6   exame_7   exame_8   exame_9  exame_10  \
# 0   -2.073335  0.984375  1.568466  3.283515  2.652874  2.532475  2.217515
# 1   -0.353632  1.908708 -0.826962 -0.487072 -0.023846  0.548144  0.001392
# 2    0.456187  1.558884  0.942210  1.052926  1.363478  2.037231  0.939685
# 3    0.253732 -0.764464  3.283553  3.402909  1.915897  1.451707  2.867383
# 4   -1.151816  1.826229  0.280372  0.539340  1.371011  1.428493 -0.009560
# 5   -0.835335 -0.505650  2.237421  1.244335  0.866302  0.824656  1.005402
# 6    0.160649  1.095295 -0.123136  0.088295  0.300072  0.646935 -0.064325
# 7    0.358450 -0.218965  1.604049  1.140102  0.061026  0.281950  1.403355
# 8    0.588830 -0.384207  2.201839  1.684010  1.219096  1.150692  1.965600
# 9    1.105439 -0.509063  1.582699  2.563358  1.738872  0.941760  0.797298
# 10   0.919273  0.406453 -1.017686 -0.713542 -0.700684 -0.404686 -1.035476
# 11  -0.325708  0.358672  0.052642  0.471115  0.134849  0.442131  0.110921
# 12   1.282296  1.331355  0.073992  2.680858  1.477729  1.621948  2.137194
# 13   1.084495  0.363507 -0.878913 -0.078478  0.132840  0.121770  0.129175
# 14   0.772668 -0.217827  1.191289  2.368158  1.556825  0.808147  0.939685
# 15   1.919912  0.011123  1.248222  1.045345  0.942887  0.637649  1.794006
# 16   0.195555  0.084216  0.164372 -0.612909 -0.186433  0.094686 -0.823721
# 17   0.323544  0.409297  1.468835  1.854573  1.047093  1.389802  1.286524
# 18   0.665623  1.720997  0.138753 -0.031099  0.742007  1.188093 -0.838325
# 19  -1.147162 -0.251957  0.101747 -0.436850 -0.278210 -0.028609  0.267911
# 20  -0.833008 -0.383638  0.792763  0.429422 -0.541362 -0.459627  0.567289
# 21  -1.593959 -1.083572  0.429819 -0.747086 -0.743748 -0.726337  0.012345
# 22  -1.170433  0.140814  0.778530  2.068725  1.492795  1.254641  2.589911
# 23   0.872732  2.130548 -0.148044 -0.040575  0.262407  0.964717 -0.155598
# 24   0.486439  0.710203  1.120124  0.783815  0.799760  1.103489  0.669515
# 25  -0.672441  0.733241  1.582699  2.335941  1.683630  2.351917  4.484751
# 26   0.521345 -0.028694  0.643316  1.562720  0.674211  1.003666  1.607807
# 27   0.223480  1.248876 -0.139504  0.042812  0.755818  0.732313 -0.418466
# 28   1.391668  0.220449  0.842579  1.238650  0.998129  0.995412  0.417600
# 29  -0.986595  0.853831  0.150139  0.215270  0.124931  0.789576 -0.265127
# ..        ...       ...       ...       ...       ...       ...       ...
# 539  1.431228 -1.377937 -0.688901  0.294866  0.046713 -0.909990  0.822855
# 540 -1.128546 -0.716683  0.247636  0.145150 -0.269044 -0.592724  0.023298
# 541  1.326510  0.004297 -0.568632  0.353616  0.151924 -0.258434  0.220449
# 542  1.426574  0.038995 -0.968582 -0.610256 -0.599491 -0.481036  0.103619
# 543  2.040920 -0.331307 -0.686767 -0.674123 -0.739856 -0.417067 -0.670381
# 544  0.328198 -0.199341 -0.041296 -0.048155 -0.651846 -0.650760 -0.699589
# 545  0.916946 -0.232332 -0.277565 -0.698760 -0.741488 -0.631673 -0.538947
# 546 -0.684076 -0.938523 -0.143774 -1.030979 -0.987817 -1.120082  0.267911
# 547 -0.630553 -0.950184 -0.540166 -0.448790 -0.567727 -0.632962 -0.520693
# 548  0.011717 -1.050012 -0.814864 -1.024157 -0.821463 -1.013810 -0.845627
# 549  1.144999 -0.834144 -1.027649 -0.726239 -0.920522 -1.051341  0.600147
# 550  0.509709 -0.837273 -1.569218 -1.176337 -1.114873 -1.261820 -0.549900
# 551  0.733108 -0.786363 -0.049836 -0.424532 -0.509221 -0.679649  0.797298
# 552  2.359728 -0.418052 -0.967870 -1.175010 -0.864150 -0.875168 -0.995315
# 553  0.616755 -1.111729 -0.281835 -0.915186 -0.613176 -0.931141 -0.436721
# 554  2.241047 -0.399850 -1.076753 -0.873682 -0.337092 -0.657467 -0.896740
# 555  1.936202 -0.948477 -0.431283 -0.526112 -0.361700 -0.555580 -0.798164
# 556  0.069894 -0.976065  0.280372 -0.555297 -1.051784 -0.973959 -0.075277
# 557  1.999032 -1.090967 -1.076753 -1.035338 -1.114873 -1.261820 -0.254174
# 558  0.788958  0.006288 -0.827674  0.543131  0.177034 -0.298156 -1.305645
# 559  1.079841 -0.714976 -0.266890 -0.042470  0.281240 -0.202977 -1.546608
# 560  1.829157 -0.154973  0.208495  0.156521 -0.554670 -0.151647 -1.002617
# 561  2.345765 -0.764748 -1.556408 -1.303122 -1.114873 -1.261820 -2.744117
# 562  2.636649  0.176365  0.600616  1.977758  2.086645  1.170295  1.155090
# 563  1.349781  1.968434  0.963560  2.260135  2.870075  2.540213  1.231760
# 564  0.721473  2.343856  1.041842  0.219060  1.947285  2.320965 -0.312589
# 565  2.085134  1.723842  0.102458 -0.017833  0.693043  1.263669 -0.217664
# 566  2.045574  0.577953 -0.840484 -0.038680  0.046588  0.105777 -0.809117
# 567  2.336457  1.735218  1.525767  3.272144  3.296944  2.658866  2.137194
# 568  1.221792 -1.347789 -3.112085 -1.150752 -1.114873 -1.261820 -0.820070
#
#      exame_11  exame_12  exame_13  ...  exame_20  exame_21  exame_23  \
# 0    2.255747  2.489734 -0.565265  ...  1.148757  0.907083 -1.359293
# 1   -0.868652  0.499255 -0.876244  ... -0.805450 -0.099444 -0.369203
# 2   -0.398008  1.228676 -0.780083  ...  0.237036  0.293559 -0.023974
# 3    4.910919  0.326373 -0.110409  ...  4.732680  2.047511  0.133984
# 4   -0.562450  1.270543 -0.790244  ... -0.361092  0.499328 -1.466770
# 5    1.890005 -0.255070 -0.592662  ...  0.134119  0.486846 -0.313836
# 6   -0.762332  0.149883 -0.804940  ... -0.829666 -0.611218  0.322883
# 7    1.660353  0.643623  0.290561  ... -0.688004  0.611669  0.401048
# 8    1.572462 -0.356850 -0.389818  ...  0.107482 -0.017363  0.822813
# 9    2.783096 -0.388250  0.693345  ... -0.321136  2.377346  2.443109
# 10  -0.826124 -0.092656 -0.054164  ... -0.719485 -0.284787  1.335771
# 11  -0.280347  0.363187 -0.420843  ... -0.055974  0.132046  0.261002
# 12   2.155097  1.986249  4.265788  ...  2.941929  3.421320  0.694167
# 13  -1.335044 -0.006757 -0.251928  ...  1.122119 -0.299917  0.322883
# 14   1.987820 -0.696838 -0.086823  ... -0.112881  1.625761  1.031253
# 15   1.130169 -0.126943 -0.333573  ... -0.238803  0.632094  1.865014
# 16  -0.507163  0.243723  0.041996  ... -0.780024 -0.646773  0.847240
# 17   1.525681  0.592011 -0.261000  ... -0.442215  0.131290  0.944946
# 18  -1.254241  1.274152 -0.362603  ... -0.845406 -0.680060  0.847240
# 19  -0.728310 -0.488225 -0.776999  ... -0.089876 -0.565449 -1.045005
# 20   0.753087 -0.793925 -0.851206  ... -0.455534 -0.518168 -0.844707
# 21   0.886341 -0.461517 -0.435539  ... -0.032970 -0.312777 -1.631243
# 22   1.066377  0.121370 -0.920332  ...  1.958772  0.226609 -1.074317
# 23  -1.420100  1.034140 -0.163025  ... -1.175951 -0.683842  1.614234
# 24   0.071219  1.449560 -0.571797  ... -0.709798 -0.375945  0.957974
# 25   1.606484  2.312883 -0.436991  ...  0.307261  1.380276 -0.696519
# 26   0.913276 -0.543807 -0.423928  ... -0.726749 -0.031737  1.226666
# 27  -0.823289  1.615944  1.146931  ...  0.289099  0.159658  0.257745
# 28   0.368916  0.122092 -0.371675  ... -0.346563 -0.313156  1.796619
# 29  -0.185367  0.704258 -0.715493  ... -0.156470 -0.020011 -1.002666
# ..        ...       ...       ...  ...       ...       ...       ...
# 539  2.085634 -0.669769  0.475624  ...  0.061472  1.420748  1.011712
# 540  0.711976 -0.457547  0.999969  ... -0.259386  0.649494 -0.976611
# 541  0.086813 -0.544890 -0.250114  ...  0.016673  0.876066  0.985657
# 542 -0.850224 -0.368399  0.305076  ... -0.223063 -0.442139  1.076850
# 543 -0.707046 -0.613826  0.689717  ... -0.399837 -0.927436  1.871527
# 544  0.578721 -0.480646 -0.308173  ... -0.683161 -0.074101 -0.150993
# 545 -0.678694 -0.213564  0.216173  ...  0.039678 -0.458404  0.555750
# 546 -0.111652 -0.702973 -0.453320  ... -0.598406 -0.449704 -0.636267
# 547  0.615579 -1.049457 -0.351717  ...  0.269727  0.792473 -0.592299
# 548 -0.063453 -0.395108  0.265160  ...  0.180129  0.135829 -0.014204
# 549  0.068384  0.412994  1.272121  ...  0.498565 -0.309373  0.940061
# 550 -0.470306 -0.320758  0.158114  ...  1.149967 -0.592683 -0.147736
# 551  0.385927 -0.451772  0.453852  ...  1.038575  0.351054  0.420589
# 552 -0.911181 -0.592892  0.272418  ... -0.190372 -0.782566  1.681000
# 553  0.419950 -0.374896  1.201362  ...  2.064110  0.313228 -0.102139
# 554 -0.810531 -0.698642  0.259717  ... -0.434950 -0.375945  1.638661
# 555 -0.216555 -0.668686  1.854525  ... -0.255754  0.432378  1.503500
# 556  0.072637 -0.581343  1.584188  ...  0.626908 -0.573771 -0.455510
# 557 -0.312952  0.477599  3.102794  ...  1.149967 -0.178120  1.394395
# 558 -0.188203 -0.648835 -0.197498  ... -0.503965  0.231148  0.259374
# 559  0.411444 -0.600472  3.061064  ... -0.685583  0.356727  1.869899
# 560 -0.154180 -0.146794  0.499211  ...  0.031202  0.570818  1.220152
# 561 -1.102557 -0.328698  4.860893  ... -0.078979 -0.764788  2.055541
# 562  1.236490 -0.523235 -0.021506  ...  0.100217  0.887792  2.786709
# 563  0.849484  2.010431 -0.346274  ...  0.003354  0.914648  0.607860
# 564 -0.931027  2.782080  0.071025  ... -1.138416  0.167980  0.117700
# 565 -1.058611  1.300499  2.260938  ... -0.189161 -0.490556  2.047399
# 566 -0.895587  0.184892 -0.257371  ... -0.891416  0.036727  1.374854
# 567  1.043695  1.157935  0.686088  ...  0.326634  0.904057  2.237926
# 568 -0.561032 -0.070279  0.383092  ...  0.752830 -0.382754  0.764190
#
#      exame_25  exame_26  exame_27  exame_28  exame_30  exame_31  exame_32
# 0    2.001237  1.307686  2.616665  2.109526  2.296076  2.750622  1.937015
# 1    1.890489 -0.375612 -0.430444 -0.146749  1.087084 -0.243890  0.281190
# 2    1.456285  0.527407  1.082932  0.854974  1.955000  1.152255  0.201391
# 3   -0.550021  3.394275  3.893397  1.989588  2.175786  6.046041  4.935010
# 4    1.220724  0.220556 -0.313395  0.613179  0.729259 -0.868353 -0.397100
# 5   -0.244320  2.048513  1.721616  1.263243  0.905888  1.754069  2.241802
# 6    1.275220  0.518640  0.021215  0.509552  1.196716  0.262476 -0.014730
# 7    0.028859  1.447961  0.724786 -0.021054  0.624196  0.477640  1.726435
# 8   -0.248363  1.662757  1.818310  1.280035  1.391616  2.389857  1.288650
# 9   -0.297409  2.320295  5.112877  3.995433  1.620015  2.370444  6.846856
# 10   0.473611 -0.625477 -0.630828 -0.605872 -0.226210  0.076431  0.031819
# 11   0.735540  0.316995  1.950627  0.596387  1.010951  1.441838  1.155652
# 12   0.793551 -1.256713  0.865372  0.439988  0.945477  0.445285  1.017112
# 13  -0.007178 -0.844656 -0.393548 -0.191846 -0.041207 -0.148441 -1.167934
# 14  -0.321493  1.434810  3.296698  2.025090  1.616970  1.124753  3.278077
# 15   0.110075  1.553167  2.566410  2.064909  0.861731  2.131012  2.779335
# 16   0.452516  0.615079 -0.427264  0.092168  0.704897  0.207471 -0.098963
# 17   0.763667  2.039746  1.075298  0.989305  1.411411  1.302709  1.676560
# 18   2.667486  0.825491  0.386359  1.271399  1.891049 -0.214770 -0.432012
# 19  -0.297761  0.509873 -0.489605 -0.159223  0.216123  0.123347 -0.629292
# 20  -0.439624 -0.051226  0.148443 -0.399099 -0.636110  0.458227 -0.117250
# 21  -0.994422  0.001377 -0.887193 -0.880434 -0.796903 -0.729224 -0.344455
# 22   0.176348  0.290694  2.170095  1.719008  1.898662  2.857396  0.859731
# 23   3.048953  0.338913  0.036482  0.207788  1.313961 -0.127409 -0.481332
# 24   2.345788  2.109883  0.658627  0.946607  1.444909  1.152255  0.648043
# 25   1.020322  0.970150  0.894635  0.542655  2.137720  1.885110  1.216609
# 26   0.028684  0.882478  2.608395  1.351518  2.367641  2.205430  2.413591
# 27   0.918363  0.062747 -0.270773  0.347396  0.523700 -0.905562 -0.539518
# 28   0.682803  1.390974  2.269333  1.733401  1.336800  1.822016  0.820940
# 29   0.608971 -0.301091  0.171344 -0.111727  0.471930 -0.234183 -0.263547
# ..        ...       ...       ...       ...       ...       ...       ...
# 539 -1.154919  1.193713  0.331651  0.321969 -0.983733 -0.179178  1.255400
# 540 -0.743216  0.093432 -0.270137 -0.443716 -0.691687 -0.924975 -0.144403
# 541 -0.126013  0.071514  1.055578  0.632369  0.089742  0.463080  1.017112
# 542 -0.095249 -1.155891 -0.742153 -0.532950 -0.077750 -0.289188 -0.797202
# 543 -0.441206 -1.103288 -0.738972 -0.796334 -0.533330 -0.692015 -1.081485
# 544 -0.337490 -0.261639 -0.321664 -0.645212 -0.702802 -1.054398  0.053985
# 545 -0.265064 -0.472051 -0.652457 -0.802570 -0.652707 -0.418610 -0.798864
# 546 -0.871368 -0.169583 -1.055006 -1.095507 -1.382518 -0.355517 -0.551710
# 547 -0.919710  0.601928 -0.188711 -0.450432 -0.476230 -0.339339  0.600939
# 548 -0.907756 -0.546572 -1.010222 -0.857262 -1.159448 -0.564210 -0.262993
# 549 -0.659188 -0.524654 -0.578665 -1.008672 -1.248067  0.256005 -0.425916
# 550 -0.823201 -1.414523 -1.150045 -1.305831 -1.745063 -0.716282 -0.998915
# 551 -0.780484 -1.037534 -0.483880 -0.555498 -0.768581  0.433960 -0.200928
# 552 -0.502558 -0.393146 -0.940628 -0.890701 -0.755639 -0.798788 -1.058764
# 553 -1.027998 -0.967396 -1.089612 -0.922365 -1.354653 -0.753491 -0.555035
# 554 -0.500800 -0.423831 -0.586935 -0.135715 -0.756400 -0.855411 -0.638713
# 555 -0.919359  0.264392 -0.529682 -0.346326 -0.355331 -1.091607 -0.061834
# 556 -0.937465 -0.257255 -0.854113 -1.257616 -1.405205 -1.033367 -0.915792
# 557 -0.966822 -1.098904 -1.162132 -1.305831 -1.745063 -0.688779 -0.789998
# 558 -0.258559 -1.304933  0.399718  0.451022 -0.062524 -1.039838 -0.216444
# 559 -0.714386 -0.112597 -0.016317  0.435670 -0.275239 -1.276034  0.186983
# 560 -0.305671 -0.362461 -0.177261 -0.669679 -0.149315 -1.052780 -0.040776
# 561 -0.775210 -1.740223 -1.267986 -1.305831 -1.745063 -2.159342 -1.379622
# 562  0.060502  0.409050  3.418837  4.307272  1.842324  1.922319  3.156163
# 563  1.649655  0.365215  1.045400  1.860055  2.125538  0.045693  0.819278
# 564  2.015301  0.378365 -0.273318  0.664512  1.629151 -1.360158 -0.709091
# 565  1.494959 -0.691230 -0.394820  0.236573  0.733827 -0.531855 -0.973978
# 566  0.427906 -0.809587  0.350735  0.326767  0.414069 -1.104549 -0.318409
# 567  1.653171  1.430427  3.904848  3.197605  2.289985  1.919083  2.219635
# 568 -1.075813 -1.859019 -1.207552 -1.305831 -1.745063 -0.048138 -0.751207
#
# [569 rows x 26 columns]

# %%
classificar(valores_exames_v4)
# Out:
# Resultado da classificação 91.81%.

# %%
valores_exames_v5 = valores_exames_v3.drop(columns=["exame_3", "exame_24"])
classificar(valores_exames_v5)
# Out:
# Resultado da classificação 92.98%.

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

selecionar_kmelhores = SelectKBest(chi2, k = 5)

# %%
treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v5, diagnostico, test_size = 0.3)
selecionar_kmelhores.fit(treino_x, treino_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-b1a8134edb61> in <module>
#       1 treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v3, diagnostico, test_size = 0.3)
# ----> 2 selecionar_kmelhores.fit(treino_x, treino_y)
#
# c:\users\ramon.nascimento\appdata\local\programs\python\python37\lib\site-packages\sklearn\feature_selection\univariate_selection.py in fit(self, X, y)
#     347
#     348         self._check_params(X, y)
# --> 349         score_func_ret = self.score_func(X, y)
#     350         if isinstance(score_func_ret, (list, tuple)):
#     351             self.scores_, self.pvalues_ = score_func_ret
#
# c:\users\ramon.nascimento\appdata\local\programs\python\python37\lib\site-packages\sklearn\feature_selection\univariate_selection.py in chi2(X, y)
#     214     X = check_array(X, accept_sparse='csr')
#     215     if np.any((X.data if issparse(X) else X) < 0):
# --> 216         raise ValueError("Input X must be non-negative.")
#     217
#     218     Y = LabelBinarizer().fit_transform(y)
#
# ValueError: Input X must be non-negative.

# %%
valores_exames_v6 = valores_exames_v1.drop(columns=(['exame_3', 'exame_4', 'exame_24', 'exame_29']))

# %%
SEED = 1234
random.seed(SEED)

treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v6, diagnostico, test_size = 0.3)
selecionar_kmelhores.fit(treino_x, treino_y)
treino_kbest = selecionar_kmelhores.transform(treino_x)
teste_kbest = selecionar_kmelhores.transform(teste_x)

# %%
teste_kbest.shape
# Out:
# (171, 5)

# %%
classificador = RandomForestClassifier(n_estimators=100, random_state=1234)
classificador.fit(treino_kbest, treino_y)
print("Resultado da classificação %.2f%%." % (classificador.score(teste_kbest, teste_y)*100))
# Out:
# Resultado da classificação 89.47%.
